# %%
import requests
import csv
import os

# %%
#Creates CSV file of the most popular actors

api_key = os.getenv("API_KEY")


url_template = "https://api.themoviedb.org/3/person/popular?language=en-US&page={}"
headers = {
    "accept": "application/json",
    "Authorization": f"Bearer {api_key}",
}

actors = []
page = 1
number_of_actors = 200

while len(actors) < number_of_actors:
    response = requests.get(url_template.format(page), headers=headers)

    if response.status_code == 200:
        data = response.json()
        for person in data.get("results", []):
            if person.get("known_for_department") == "Acting":
                actors.append((person["name"], person["id"]))
                if len(actors) == number_of_actors:
                    break  # Stop once we have the requested amount of actors
    else:
        print("Error:", response.status_code, response.text)
        break

    page += 1  # Go to the next page

# Write to CSV
with open("actors.csv", "w", newline="", encoding="utf-8") as file:
    writer = csv.writer(file)
    writer.writerow(["Name", "Person_ID"])
    writer.writerows(actors)

print("CSV file 'actors.csv' with 200 actors created successfully!")
# Out:
# CSV file 'actors.csv' with 100 actors created successfully!

# %%
#takes the actors from the CSV file and downloads their images
# TMDb API Key


folder_name = "actors_DB"
number_of_folders = 200
number_of_images = 5

# Read first 15 people from CSV
actors = []
with open("actors.csv", "r", encoding="utf-8") as file:
    reader = csv.reader(file)
    next(reader)  # Skip header
    for i, row in enumerate(reader):
        if i >= number_of_folders:  # Only process first 15 actors
            break
        actors.append((row[0], row[1]))  # (Name, Person_ID)

# Base directory for images
base_dir = folder_name
os.makedirs(base_dir, exist_ok=True)

# Download images for each actor
for name, person_id in actors:
    # API request URL for images
    url = f"https://api.themoviedb.org/3/person/{person_id}/images"
    headers = {
        "accept": "application/json",
        "Authorization": f"Bearer {api_key}"
    }
    
    # Request images
    response = requests.get(url, headers=headers)
    
    if response.status_code == 200:
        data = response.json()
        profiles = data.get("profiles", [])[:number_of_images]  # Get up to 5 images
        
        # Create folder for the actor
        person_folder = os.path.join(base_dir, name.replace(" ", "_"))
        os.makedirs(person_folder, exist_ok=True)
        
        # Download images
        for idx, profile in enumerate(profiles):
            file_path = profile.get("file_path")  # Extract "file_path"
            if file_path:
                image_url = f"https://image.tmdb.org/t/p/original{file_path}"
                image_path = os.path.join(person_folder, f"image_{idx+1}.jpg")
                
                # Download and save image
                img_data = requests.get(image_url).content
                with open(image_path, "wb") as img_file:
                    img_file.write(img_data)
                
                print(f"Downloaded: {image_path}")
    
    else:
        print(f"Failed to get images for {name} (ID: {person_id})")

print("Image download complete!")
# Out:
# Downloaded: actors_DB\Hande_Erçel\image_1.jpg
# Downloaded: actors_DB\Hande_Erçel\image_2.jpg
# Downloaded: actors_DB\Hande_Erçel\image_3.jpg
# Downloaded: actors_DB\Hande_Erçel\image_4.jpg
# Downloaded: actors_DB\Hande_Erçel\image_5.jpg
# Downloaded: actors_DB\Alexandra_Daddario\image_1.jpg
# Downloaded: actors_DB\Alexandra_Daddario\image_2.jpg
# Downloaded: actors_DB\Alexandra_Daddario\image_3.jpg
# Downloaded: actors_DB\Alexandra_Daddario\image_4.jpg
# Downloaded: actors_DB\Alexandra_Daddario\image_5.jpg
# Downloaded: actors_DB\Timothée_Chalamet\image_1.jpg
# Downloaded: actors_DB\Timothée_Chalamet\image_2.jpg
# Downloaded: actors_DB\Timothée_Chalamet\image_3.jpg
# Downloaded: actors_DB\Timothée_Chalamet\image_4.jpg
# Downloaded: actors_DB\Timothée_Chalamet\image_5.jpg
# Downloaded: actors_DB\Anya_Taylor-Joy\image_1.jpg
# Downloaded: actors_DB\Anya_Taylor-Joy\image_2.jpg
# Downloaded: actors_DB\Anya_Taylor-Joy\image_3.jpg
# Downloaded: actors_DB\Anya_Taylor-Joy\image_4.jpg
# Downloaded: actors_DB\Anya_Taylor-Joy\image_5.jpg
# Downloaded: actors_DB\Jason_Statham\image_1.jpg
# Downloaded: actors_DB\Jason_Statham\image_2.jpg
# Downloaded: actors_DB\Jason_Statham\image_3.jpg
# Downloaded: actors_DB\Jason_Statham\image_4.jpg
# Downloaded: actors_DB\Jason_Statham\image_5.jpg
# Downloaded: actors_DB\Scarlett_Johansson\image_1.jpg
# Downloaded: actors_DB\Scarlett_Johansson\image_2.jpg
# Downloaded: actors_DB\Scarlett_Johansson\image_3.jpg
# Downloaded: actors_DB\Scarlett_Johansson\image_4.jpg
# Downloaded: actors_DB\Scarlett_Johansson\image_5.jpg
# Downloaded: actors_DB\Sydney_Sweeney\image_1.jpg
# Downloaded: actors_DB\Sydney_Sweeney\image_2.jpg
# Downloaded: actors_DB\Sydney_Sweeney\image_3.jpg
# Downloaded: actors_DB\Sydney_Sweeney\image_4.jpg
# Downloaded: actors_DB\Sydney_Sweeney\image_5.jpg
# Downloaded: actors_DB\Zhao_Lusi\image_1.jpg
# Downloaded: actors_DB\Zhao_Lusi\image_2.jpg
# Downloaded: actors_DB\Zhao_Lusi\image_3.jpg
# Downloaded: actors_DB\Zhao_Lusi\image_4.jpg
# Downloaded: actors_DB\Zhao_Lusi\image_5.jpg
# Downloaded: actors_DB\Tom_Cruise\image_1.jpg
# Downloaded: actors_DB\Tom_Cruise\image_2.jpg
# Downloaded: actors_DB\Tom_Cruise\image_3.jpg
# Downloaded: actors_DB\Tom_Cruise\image_4.jpg
# Downloaded: actors_DB\Tom_Cruise\image_5.jpg
# Downloaded: actors_DB\Gary_Oldman\image_1.jpg
# Downloaded: actors_DB\Gary_Oldman\image_2.jpg
# Downloaded: actors_DB\Gary_Oldman\image_3.jpg
# Downloaded: actors_DB\Gary_Oldman\image_4.jpg
# Downloaded: actors_DB\Gary_Oldman\image_5.jpg
# Downloaded: actors_DB\Sophie_Thatcher\image_1.jpg
# Downloaded: actors_DB\Sophie_Thatcher\image_2.jpg
# Downloaded: actors_DB\Sophie_Thatcher\image_3.jpg
# Downloaded: actors_DB\Sophie_Thatcher\image_4.jpg
# Downloaded: actors_DB\Sophie_Thatcher\image_5.jpg
# Downloaded: actors_DB\Gabriel_Guevara\image_1.jpg
# Downloaded: actors_DB\Jenna_Ortega\image_1.jpg
# Downloaded: actors_DB\Jenna_Ortega\image_2.jpg
# Downloaded: actors_DB\Jenna_Ortega\image_3.jpg
# Downloaded: actors_DB\Jenna_Ortega\image_4.jpg
# Downloaded: actors_DB\Jenna_Ortega\image_5.jpg
# Downloaded: actors_DB\Elizabeth_Berkley\image_1.jpg
# Downloaded: actors_DB\Elizabeth_Berkley\image_2.jpg
# Downloaded: actors_DB\Elizabeth_Berkley\image_3.jpg
# Downloaded: actors_DB\Elizabeth_Berkley\image_4.jpg
# Downloaded: actors_DB\Elizabeth_Berkley\image_5.jpg
# Downloaded: actors_DB\Cho_Yeo-jeong\image_1.jpg
# Downloaded: actors_DB\Cho_Yeo-jeong\image_2.jpg
# Downloaded: actors_DB\Cho_Yeo-jeong\image_3.jpg
# Downloaded: actors_DB\Cho_Yeo-jeong\image_4.jpg
# Downloaded: actors_DB\Cho_Yeo-jeong\image_5.jpg
# Downloaded: actors_DB\Sabrina_Carpenter\image_1.jpg
# Downloaded: actors_DB\Sabrina_Carpenter\image_2.jpg
# Downloaded: actors_DB\Sabrina_Carpenter\image_3.jpg
# Downloaded: actors_DB\Sabrina_Carpenter\image_4.jpg
# Downloaded: actors_DB\Sabrina_Carpenter\image_5.jpg
# Downloaded: actors_DB\Cha_Woo-min\image_1.jpg
# Downloaded: actors_DB\Cha_Woo-min\image_2.jpg
# Downloaded: actors_DB\Cha_Woo-min\image_3.jpg
# Downloaded: actors_DB\Christine_Bermas\image_1.jpg
# Downloaded: actors_DB\Robert_Downey_Jr.\image_1.jpg
# Downloaded: actors_DB\Robert_Downey_Jr.\image_2.jpg
# Downloaded: actors_DB\Robert_Downey_Jr.\image_3.jpg
# Downloaded: actors_DB\Robert_Downey_Jr.\image_4.jpg
# Downloaded: actors_DB\Robert_Downey_Jr.\image_5.jpg
# Downloaded: actors_DB\Keanu_Reeves\image_1.jpg
# Downloaded: actors_DB\Keanu_Reeves\image_2.jpg
# Downloaded: actors_DB\Keanu_Reeves\image_3.jpg
# Downloaded: actors_DB\Keanu_Reeves\image_4.jpg
# Downloaded: actors_DB\Keanu_Reeves\image_5.jpg
# Downloaded: actors_DB\Nicole_Wallace\image_1.jpg
# Downloaded: actors_DB\Nicole_Wallace\image_2.jpg
# Downloaded: actors_DB\Nicole_Wallace\image_3.jpg
# Downloaded: actors_DB\Nicole_Wallace\image_4.jpg
# Downloaded: actors_DB\Nicole_Wallace\image_5.jpg
# Downloaded: actors_DB\Emma_Watson\image_1.jpg
# Downloaded: actors_DB\Emma_Watson\image_2.jpg
# Downloaded: actors_DB\Emma_Watson\image_3.jpg
# Downloaded: actors_DB\Emma_Watson\image_4.jpg
# Downloaded: actors_DB\Emma_Watson\image_5.jpg
# Downloaded: actors_DB\Pedro_Pascal\image_1.jpg
# Downloaded: actors_DB\Pedro_Pascal\image_2.jpg
# Downloaded: actors_DB\Pedro_Pascal\image_3.jpg
# Downloaded: actors_DB\Pedro_Pascal\image_4.jpg
# Downloaded: actors_DB\Pedro_Pascal\image_5.jpg
# Downloaded: actors_DB\Atsuko_Takahata\image_1.jpg
# Downloaded: actors_DB\Dyessa_Garcia\image_1.jpg
# Downloaded: actors_DB\Yoon_Yool\image_1.jpg
# Downloaded: actors_DB\Yoon_Yool\image_2.jpg
# Downloaded: actors_DB\Yoon_Yool\image_3.jpg
# Downloaded: actors_DB\Miles_Teller\image_1.jpg
# Downloaded: actors_DB\Miles_Teller\image_2.jpg
# Downloaded: actors_DB\Miles_Teller\image_3.jpg
# Downloaded: actors_DB\Miles_Teller\image_4.jpg
# Downloaded: actors_DB\Miles_Teller\image_5.jpg
# Downloaded: actors_DB\Kim_Kardashian\image_1.jpg
# Downloaded: actors_DB\Kim_Kardashian\image_2.jpg
# Downloaded: actors_DB\Kim_Kardashian\image_3.jpg
# Downloaded: actors_DB\Kim_Kardashian\image_4.jpg
# Downloaded: actors_DB\Kim_Kardashian\image_5.jpg
# Downloaded: actors_DB\Ana_de_Armas\image_1.jpg
# Downloaded: actors_DB\Ana_de_Armas\image_2.jpg
# Downloaded: actors_DB\Ana_de_Armas\image_3.jpg
# Downloaded: actors_DB\Ana_de_Armas\image_4.jpg
# Downloaded: actors_DB\Ana_de_Armas\image_5.jpg
# Downloaded: actors_DB\Julia_Victoria\image_1.jpg
# Downloaded: actors_DB\Angelica_Hart\image_1.jpg
# Downloaded: actors_DB\Arya_Mohan\image_1.jpg
# Downloaded: actors_DB\Yoo_Ji-hyun\image_1.jpg
# Downloaded: actors_DB\Anne_Hathaway\image_1.jpg
# Downloaded: actors_DB\Anne_Hathaway\image_2.jpg
# Downloaded: actors_DB\Anne_Hathaway\image_3.jpg
# Downloaded: actors_DB\Anne_Hathaway\image_4.jpg
# Downloaded: actors_DB\Anne_Hathaway\image_5.jpg
# Downloaded: actors_DB\Chris_Hemsworth\image_1.jpg
# Downloaded: actors_DB\Chris_Hemsworth\image_2.jpg
# Downloaded: actors_DB\Chris_Hemsworth\image_3.jpg
# Downloaded: actors_DB\Chris_Hemsworth\image_4.jpg
# Downloaded: actors_DB\Chris_Hemsworth\image_5.jpg
# Downloaded: actors_DB\Joo_Ye-bin\image_1.jpg
# Downloaded: actors_DB\Shinobu_Terajima\image_1.jpg
# Downloaded: actors_DB\Shinobu_Terajima\image_2.jpg
# Downloaded: actors_DB\Yu_Aoi\image_1.jpg
# Downloaded: actors_DB\Yu_Aoi\image_2.jpg
# Downloaded: actors_DB\Yu_Aoi\image_3.jpg
# Downloaded: actors_DB\Yu_Aoi\image_4.jpg
# Downloaded: actors_DB\Yu_Aoi\image_5.jpg
# Downloaded: actors_DB\Theo_James\image_1.jpg
# Downloaded: actors_DB\Theo_James\image_2.jpg
# Downloaded: actors_DB\Theo_James\image_3.jpg
# Downloaded: actors_DB\Theo_James\image_4.jpg
# Downloaded: actors_DB\Theo_James\image_5.jpg
# Downloaded: actors_DB\Katheryn_Winnick\image_1.jpg
# Downloaded: actors_DB\Katheryn_Winnick\image_2.jpg
# Downloaded: actors_DB\Katheryn_Winnick\image_3.jpg
# Downloaded: actors_DB\Katheryn_Winnick\image_4.jpg
# Downloaded: actors_DB\Katheryn_Winnick\image_5.jpg
# Downloaded: actors_DB\Justin_Baldoni\image_1.jpg
# Downloaded: actors_DB\Justin_Baldoni\image_2.jpg
# Downloaded: actors_DB\Justin_Baldoni\image_3.jpg
# Downloaded: actors_DB\Justin_Baldoni\image_4.jpg
# Downloaded: actors_DB\Justin_Baldoni\image_5.jpg
# Downloaded: actors_DB\Kevin_Bacon\image_1.jpg
# Downloaded: actors_DB\Kevin_Bacon\image_2.jpg
# Downloaded: actors_DB\Kevin_Bacon\image_3.jpg
# Downloaded: actors_DB\Kevin_Bacon\image_4.jpg
# Downloaded: actors_DB\Miho_Nomoto\image_1.jpg
# Downloaded: actors_DB\Tom_Hanks\image_1.jpg
# Downloaded: actors_DB\Tom_Hanks\image_2.jpg
# Downloaded: actors_DB\Tom_Hanks\image_3.jpg
# Downloaded: actors_DB\Tom_Hanks\image_4.jpg
# Downloaded: actors_DB\Tom_Hanks\image_5.jpg
# Downloaded: actors_DB\Tom_Holland\image_1.jpg
# Downloaded: actors_DB\Tom_Holland\image_2.jpg
# Downloaded: actors_DB\Tom_Holland\image_3.jpg
# Downloaded: actors_DB\Tom_Holland\image_4.jpg
# Downloaded: actors_DB\Tom_Holland\image_5.jpg
# Downloaded: actors_DB\Vin_Diesel\image_1.jpg
# Downloaded: actors_DB\Vin_Diesel\image_2.jpg
# Downloaded: actors_DB\Vin_Diesel\image_3.jpg
# Downloaded: actors_DB\Vin_Diesel\image_4.jpg
# Downloaded: actors_DB\Vin_Diesel\image_5.jpg
# Downloaded: actors_DB\Mel_Gibson\image_1.jpg
# Downloaded: actors_DB\Mel_Gibson\image_2.jpg
# Downloaded: actors_DB\Mel_Gibson\image_3.jpg
# Downloaded: actors_DB\Mel_Gibson\image_4.jpg
# Downloaded: actors_DB\Mel_Gibson\image_5.jpg
# Downloaded: actors_DB\Gal_Gadot\image_1.jpg
# Downloaded: actors_DB\Gal_Gadot\image_2.jpg
# Downloaded: actors_DB\Gal_Gadot\image_3.jpg
# Downloaded: actors_DB\Gal_Gadot\image_4.jpg
# Downloaded: actors_DB\Gal_Gadot\image_5.jpg
# Downloaded: actors_DB\Sena_Natsuki\image_1.jpg
# Downloaded: actors_DB\Dwayne_Johnson\image_1.jpg
# Downloaded: actors_DB\Dwayne_Johnson\image_2.jpg
# Downloaded: actors_DB\Dwayne_Johnson\image_3.jpg
# Downloaded: actors_DB\Dwayne_Johnson\image_4.jpg
# Downloaded: actors_DB\Dwayne_Johnson\image_5.jpg
# Downloaded: actors_DB\Alan_Ritchson\image_1.jpg
# Downloaded: actors_DB\Alan_Ritchson\image_2.jpg
# Downloaded: actors_DB\Alan_Ritchson\image_3.jpg
# Downloaded: actors_DB\Alan_Ritchson\image_4.jpg
# Downloaded: actors_DB\Alan_Ritchson\image_5.jpg
# Downloaded: actors_DB\Lee_Soo\image_1.jpg
# Downloaded: actors_DB\Lee_Soo\image_2.jpg
# Downloaded: actors_DB\Lee_Soo\image_3.jpg
# Downloaded: actors_DB\Lee_Soo\image_4.jpg
# Downloaded: actors_DB\Tom_Hardy\image_1.jpg
# Downloaded: actors_DB\Tom_Hardy\image_2.jpg
# Downloaded: actors_DB\Tom_Hardy\image_3.jpg
# Downloaded: actors_DB\Tom_Hardy\image_4.jpg
# Downloaded: actors_DB\Tom_Hardy\image_5.jpg
# Downloaded: actors_DB\Leonardo_DiCaprio\image_1.jpg
# Downloaded: actors_DB\Leonardo_DiCaprio\image_2.jpg
# Downloaded: actors_DB\Leonardo_DiCaprio\image_3.jpg
# Downloaded: actors_DB\Leonardo_DiCaprio\image_4.jpg
# Downloaded: actors_DB\Leonardo_DiCaprio\image_5.jpg
# Downloaded: actors_DB\Henry_Cavill\image_1.jpg
# Downloaded: actors_DB\Henry_Cavill\image_2.jpg
# Downloaded: actors_DB\Henry_Cavill\image_3.jpg
# Downloaded: actors_DB\Henry_Cavill\image_4.jpg
# Downloaded: actors_DB\Henry_Cavill\image_5.jpg
# Downloaded: actors_DB\Joe_Anders\image_1.jpg
# Downloaded: actors_DB\Aaron_Pierre\image_1.jpg
# Downloaded: actors_DB\Aaron_Pierre\image_2.jpg
# Downloaded: actors_DB\Aaron_Pierre\image_3.jpg
# Downloaded: actors_DB\Aaron_Pierre\image_4.jpg
# Downloaded: actors_DB\Aaron_Pierre\image_5.jpg
# Downloaded: actors_DB\Anthony_Mackie\image_1.jpg
# Downloaded: actors_DB\Anthony_Mackie\image_2.jpg
# Downloaded: actors_DB\Anthony_Mackie\image_3.jpg
# Downloaded: actors_DB\Anthony_Mackie\image_4.jpg
# Downloaded: actors_DB\Anthony_Mackie\image_5.jpg
# Downloaded: actors_DB\Carla_Tous\image_1.jpg
# Downloaded: actors_DB\Andrew_Garfield\image_1.jpg
# Downloaded: actors_DB\Andrew_Garfield\image_2.jpg
# Downloaded: actors_DB\Andrew_Garfield\image_3.jpg
# Downloaded: actors_DB\Andrew_Garfield\image_4.jpg
# Downloaded: actors_DB\Andrew_Garfield\image_5.jpg
# Downloaded: actors_DB\Burak_Özçivit\image_1.jpg
# Downloaded: actors_DB\Burak_Özçivit\image_2.jpg
# Downloaded: actors_DB\Burak_Özçivit\image_3.jpg
# Downloaded: actors_DB\Burak_Özçivit\image_4.jpg
# Downloaded: actors_DB\Burak_Özçivit\image_5.jpg
# Downloaded: actors_DB\Ali_Larter\image_1.jpg
# Downloaded: actors_DB\Ali_Larter\image_2.jpg
# Downloaded: actors_DB\Ali_Larter\image_3.jpg
# Downloaded: actors_DB\Ali_Larter\image_4.jpg
# Downloaded: actors_DB\Ali_Larter\image_5.jpg
# Downloaded: actors_DB\Brad_Pitt\image_1.jpg
# Downloaded: actors_DB\Brad_Pitt\image_2.jpg
# Downloaded: actors_DB\Brad_Pitt\image_3.jpg
# Downloaded: actors_DB\Brad_Pitt\image_4.jpg
# Downloaded: actors_DB\Brad_Pitt\image_5.jpg
# Downloaded: actors_DB\Margaret_Qualley\image_1.jpg
# Downloaded: actors_DB\Margaret_Qualley\image_2.jpg
# Downloaded: actors_DB\Margaret_Qualley\image_3.jpg
# Downloaded: actors_DB\Margaret_Qualley\image_4.jpg
# Downloaded: actors_DB\Margaret_Qualley\image_5.jpg
# Downloaded: actors_DB\Kevin_Hart\image_1.jpg
# Downloaded: actors_DB\Kevin_Hart\image_2.jpg
# Downloaded: actors_DB\Kevin_Hart\image_3.jpg
# Downloaded: actors_DB\Kevin_Hart\image_4.jpg
# Downloaded: actors_DB\Kevin_Hart\image_5.jpg
# Downloaded: actors_DB\Chen_Zheyuan\image_1.jpg
# Downloaded: actors_DB\Chen_Zheyuan\image_2.jpg
# Downloaded: actors_DB\Chen_Zheyuan\image_3.jpg
# Downloaded: actors_DB\Chen_Zheyuan\image_4.jpg
# Downloaded: actors_DB\Rika\image_1.jpg
# Downloaded: actors_DB\Eddie_Murphy\image_1.jpg
# Downloaded: actors_DB\Eddie_Murphy\image_2.jpg
# Downloaded: actors_DB\Eddie_Murphy\image_3.jpg
# Downloaded: actors_DB\Eddie_Murphy\image_4.jpg
# Downloaded: actors_DB\Eddie_Murphy\image_5.jpg
# Downloaded: actors_DB\Kevin_Costner\image_1.jpg
# Downloaded: actors_DB\Kevin_Costner\image_2.jpg
# Downloaded: actors_DB\Kevin_Costner\image_3.jpg
# Downloaded: actors_DB\Kevin_Costner\image_4.jpg
# Downloaded: actors_DB\Kevin_Costner\image_5.jpg
# Downloaded: actors_DB\Robert_Pattinson\image_1.jpg
# Downloaded: actors_DB\Robert_Pattinson\image_2.jpg
# Downloaded: actors_DB\Robert_Pattinson\image_3.jpg
# Downloaded: actors_DB\Robert_Pattinson\image_4.jpg
# Downloaded: actors_DB\Robert_Pattinson\image_5.jpg
# Downloaded: actors_DB\Samuel_L._Jackson\image_1.jpg
# Downloaded: actors_DB\Samuel_L._Jackson\image_2.jpg
# Downloaded: actors_DB\Samuel_L._Jackson\image_3.jpg
# Downloaded: actors_DB\Samuel_L._Jackson\image_4.jpg
# Downloaded: actors_DB\Samuel_L._Jackson\image_5.jpg
# Downloaded: actors_DB\Kaylah_Zander\image_1.jpg
# Downloaded: actors_DB\Kaylah_Zander\image_2.jpg
# Downloaded: actors_DB\Kaylah_Zander\image_3.jpg
# Downloaded: actors_DB\Kaylah_Zander\image_4.jpg
# Downloaded: actors_DB\Ji_Chang-wook\image_1.jpg
# Downloaded: actors_DB\Ji_Chang-wook\image_2.jpg
# Downloaded: actors_DB\Ji_Chang-wook\image_3.jpg
# Downloaded: actors_DB\Ji_Chang-wook\image_4.jpg
# Downloaded: actors_DB\Ji_Chang-wook\image_5.jpg
# Downloaded: actors_DB\Natalie_Portman\image_1.jpg
# Downloaded: actors_DB\Natalie_Portman\image_2.jpg
# Downloaded: actors_DB\Natalie_Portman\image_3.jpg
# Downloaded: actors_DB\Natalie_Portman\image_4.jpg
# Downloaded: actors_DB\Natalie_Portman\image_5.jpg
# Downloaded: actors_DB\Mikey_Madison\image_1.jpg
# Downloaded: actors_DB\Mikey_Madison\image_2.jpg
# Downloaded: actors_DB\Mikey_Madison\image_3.jpg
# Downloaded: actors_DB\Mikey_Madison\image_4.jpg
# Downloaded: actors_DB\Mikey_Madison\image_5.jpg
# Downloaded: actors_DB\Han_Yi-seul\image_1.jpg
# Downloaded: actors_DB\Han_Yi-seul\image_2.jpg
# Downloaded: actors_DB\Min_Do-yoon\image_1.jpg
# Downloaded: actors_DB\Rebecca_Ferguson\image_1.jpg
# Downloaded: actors_DB\Rebecca_Ferguson\image_2.jpg
# Downloaded: actors_DB\Rebecca_Ferguson\image_3.jpg
# Downloaded: actors_DB\Rebecca_Ferguson\image_4.jpg
# Downloaded: actors_DB\Rebecca_Ferguson\image_5.jpg
# Downloaded: actors_DB\Ryan_Reynolds\image_1.jpg
# Downloaded: actors_DB\Ryan_Reynolds\image_2.jpg
# Downloaded: actors_DB\Ryan_Reynolds\image_3.jpg
# Downloaded: actors_DB\Ryan_Reynolds\image_4.jpg
# Downloaded: actors_DB\Ryan_Reynolds\image_5.jpg
# Downloaded: actors_DB\Chris_Evans\image_1.jpg
# Downloaded: actors_DB\Chris_Evans\image_2.jpg
# Downloaded: actors_DB\Chris_Evans\image_3.jpg
# Downloaded: actors_DB\Chris_Evans\image_4.jpg
# Downloaded: actors_DB\Chris_Evans\image_5.jpg
# Downloaded: actors_DB\Deniz_Can_Aktaş\image_1.jpg
# Downloaded: actors_DB\Deniz_Can_Aktaş\image_2.jpg
# Downloaded: actors_DB\Kim_Do-hee\image_1.jpg
# Downloaded: actors_DB\Jackie_Chan\image_1.jpg
# Downloaded: actors_DB\Jackie_Chan\image_2.jpg
# Downloaded: actors_DB\Jackie_Chan\image_3.jpg
# Downloaded: actors_DB\Jackie_Chan\image_4.jpg
# Downloaded: actors_DB\Jackie_Chan\image_5.jpg
# Downloaded: actors_DB\Will_Smith\image_1.jpg
# Downloaded: actors_DB\Will_Smith\image_2.jpg
# Downloaded: actors_DB\Will_Smith\image_3.jpg
# Downloaded: actors_DB\Will_Smith\image_4.jpg
# Downloaded: actors_DB\Will_Smith\image_5.jpg
# Downloaded: actors_DB\Robert_De_Niro\image_1.jpg
# Downloaded: actors_DB\Robert_De_Niro\image_2.jpg
# Downloaded: actors_DB\Robert_De_Niro\image_3.jpg
# Downloaded: actors_DB\Robert_De_Niro\image_4.jpg
# Downloaded: actors_DB\Robert_De_Niro\image_5.jpg
# Downloaded: actors_DB\Yen_Renee_Durano\image_1.jpg
# Downloaded: actors_DB\Kelly_Reilly\image_1.jpg
# Downloaded: actors_DB\Kelly_Reilly\image_2.jpg
# Downloaded: actors_DB\Kelly_Reilly\image_3.jpg
# Downloaded: actors_DB\Kelly_Reilly\image_4.jpg
# Downloaded: actors_DB\Jackie_Sandler\image_1.jpg
# Downloaded: actors_DB\Han_Seo-ah\image_1.jpg
# Downloaded: actors_DB\Han_Seo-ah\image_2.jpg
# Downloaded: actors_DB\Han_Seo-ah\image_3.jpg
# Downloaded: actors_DB\Millie_Bobby_Brown\image_1.jpg
# Downloaded: actors_DB\Millie_Bobby_Brown\image_2.jpg
# Downloaded: actors_DB\Millie_Bobby_Brown\image_3.jpg
# Downloaded: actors_DB\Millie_Bobby_Brown\image_4.jpg
# Downloaded: actors_DB\Millie_Bobby_Brown\image_5.jpg
# Downloaded: actors_DB\Jin_Si-ah\image_1.jpg
# Downloaded: actors_DB\Jin_Si-ah\image_2.jpg
# Downloaded: actors_DB\Amanda_Seyfried\image_1.jpg
# Downloaded: actors_DB\Amanda_Seyfried\image_2.jpg
# Downloaded: actors_DB\Amanda_Seyfried\image_3.jpg
# Downloaded: actors_DB\Amanda_Seyfried\image_4.jpg
# Downloaded: actors_DB\Amanda_Seyfried\image_5.jpg
# Downloaded: actors_DB\Piper_Perabo\image_1.jpg
# Downloaded: actors_DB\Piper_Perabo\image_2.jpg
# Downloaded: actors_DB\Piper_Perabo\image_3.jpg
# Downloaded: actors_DB\Piper_Perabo\image_4.jpg
# Downloaded: actors_DB\Piper_Perabo\image_5.jpg
# Downloaded: actors_DB\Margot_Robbie\image_1.jpg
# Downloaded: actors_DB\Margot_Robbie\image_2.jpg
# Downloaded: actors_DB\Margot_Robbie\image_3.jpg
# Downloaded: actors_DB\Margot_Robbie\image_4.jpg
# Downloaded: actors_DB\Margot_Robbie\image_5.jpg
# Downloaded: actors_DB\Hee-jeong\image_1.jpg
# Downloaded: actors_DB\Choi_Seung-hyun\image_1.jpg
# Downloaded: actors_DB\Choi_Seung-hyun\image_2.jpg
# Downloaded: actors_DB\Choi_Seung-hyun\image_3.jpg
# Downloaded: actors_DB\Choi_Seung-hyun\image_4.jpg
# Downloaded: actors_DB\Yang_Mi\image_1.jpg
# Downloaded: actors_DB\Yang_Mi\image_2.jpg
# Downloaded: actors_DB\Yang_Mi\image_3.jpg
# Downloaded: actors_DB\Yang_Mi\image_4.jpg
# Downloaded: actors_DB\Harrison_Ford\image_1.jpg
# Downloaded: actors_DB\Harrison_Ford\image_2.jpg
# Downloaded: actors_DB\Harrison_Ford\image_3.jpg
# Downloaded: actors_DB\Harrison_Ford\image_4.jpg
# Downloaded: actors_DB\Harrison_Ford\image_5.jpg
# Downloaded: actors_DB\Dai_Gaozheng\image_1.jpg
# Downloaded: actors_DB\Dai_Gaozheng\image_2.jpg
# Downloaded: actors_DB\Dai_Gaozheng\image_3.jpg
# Downloaded: actors_DB\Dai_Gaozheng\image_4.jpg
# Downloaded: actors_DB\Michael_B._Jordan\image_1.jpg
# Downloaded: actors_DB\Michael_B._Jordan\image_2.jpg
# Downloaded: actors_DB\Michael_B._Jordan\image_3.jpg
# Downloaded: actors_DB\Michael_B._Jordan\image_4.jpg
# Downloaded: actors_DB\Michael_B._Jordan\image_5.jpg
# Downloaded: actors_DB\Charlotte_McKinney\image_1.jpg
# Downloaded: actors_DB\Zhao_Liying\image_1.jpg
# Downloaded: actors_DB\Zhao_Liying\image_2.jpg
# Downloaded: actors_DB\Zhao_Liying\image_3.jpg
# Downloaded: actors_DB\Zhao_Liying\image_4.jpg
# Downloaded: actors_DB\Zhao_Liying\image_5.jpg
# Downloaded: actors_DB\Yvonne_Yung_Hung\image_1.jpg
# Downloaded: actors_DB\Yvonne_Yung_Hung\image_2.jpg
# Downloaded: actors_DB\Sylvester_Stallone\image_1.jpg
# Downloaded: actors_DB\Sylvester_Stallone\image_2.jpg
# Downloaded: actors_DB\Sylvester_Stallone\image_3.jpg
# Downloaded: actors_DB\Sylvester_Stallone\image_4.jpg
# Downloaded: actors_DB\Sylvester_Stallone\image_5.jpg
# Downloaded: actors_DB\Jennifer_Connelly\image_1.jpg
# Downloaded: actors_DB\Jennifer_Connelly\image_2.jpg
# Downloaded: actors_DB\Jennifer_Connelly\image_3.jpg
# Downloaded: actors_DB\Jennifer_Connelly\image_4.jpg
# Downloaded: actors_DB\Jennifer_Connelly\image_5.jpg
# Downloaded: actors_DB\Samantha_Coughlan\image_1.jpg
# Downloaded: actors_DB\Lou_Goossens\image_1.jpg
# Downloaded: actors_DB\Ralph_Fiennes\image_1.jpg
# Downloaded: actors_DB\Ralph_Fiennes\image_2.jpg
# Downloaded: actors_DB\Ralph_Fiennes\image_3.jpg
# Downloaded: actors_DB\Ralph_Fiennes\image_4.jpg
# Downloaded: actors_DB\Ralph_Fiennes\image_5.jpg
# Downloaded: actors_DB\Felicity_Jones\image_1.jpg
# Downloaded: actors_DB\Felicity_Jones\image_2.jpg
# Downloaded: actors_DB\Felicity_Jones\image_3.jpg
# Downloaded: actors_DB\Felicity_Jones\image_4.jpg
# Downloaded: actors_DB\Felicity_Jones\image_5.jpg
# Downloaded: actors_DB\Han_Mo\image_1.jpg
# Downloaded: actors_DB\Jean-Claude_Van_Damme\image_1.jpg
# Downloaded: actors_DB\Jean-Claude_Van_Damme\image_2.jpg
# Downloaded: actors_DB\Jean-Claude_Van_Damme\image_3.jpg
# Downloaded: actors_DB\Jean-Claude_Van_Damme\image_4.jpg
# Downloaded: actors_DB\Jean-Claude_Van_Damme\image_5.jpg
# Downloaded: actors_DB\Megan_Fox\image_1.jpg
# Downloaded: actors_DB\Megan_Fox\image_2.jpg
# Downloaded: actors_DB\Megan_Fox\image_3.jpg
# Downloaded: actors_DB\Megan_Fox\image_4.jpg
# Downloaded: actors_DB\Megan_Fox\image_5.jpg
# Downloaded: actors_DB\Chung_Su-bin\image_1.jpg
# Downloaded: actors_DB\Nicole_Kidman\image_1.jpg
# Downloaded: actors_DB\Nicole_Kidman\image_2.jpg
# Downloaded: actors_DB\Nicole_Kidman\image_3.jpg
# Downloaded: actors_DB\Nicole_Kidman\image_4.jpg
# Downloaded: actors_DB\Nicole_Kidman\image_5.jpg
# Downloaded: actors_DB\Benedict_Cumberbatch\image_1.jpg
# Downloaded: actors_DB\Benedict_Cumberbatch\image_2.jpg
# Downloaded: actors_DB\Benedict_Cumberbatch\image_3.jpg
# Downloaded: actors_DB\Benedict_Cumberbatch\image_4.jpg
# Downloaded: actors_DB\Benedict_Cumberbatch\image_5.jpg
# Downloaded: actors_DB\Adam_Sandler\image_1.jpg
# Downloaded: actors_DB\Adam_Sandler\image_2.jpg
# Downloaded: actors_DB\Adam_Sandler\image_3.jpg
# Downloaded: actors_DB\Adam_Sandler\image_4.jpg
# Downloaded: actors_DB\Adam_Sandler\image_5.jpg
# Downloaded: actors_DB\TJ_Bhanu\image_1.jpg
# Downloaded: actors_DB\TJ_Bhanu\image_2.jpg
# Downloaded: actors_DB\Park_Bo-young\image_1.jpg
# Downloaded: actors_DB\Park_Bo-young\image_2.jpg
# Downloaded: actors_DB\Park_Bo-young\image_3.jpg
# Downloaded: actors_DB\Park_Bo-young\image_4.jpg
# Downloaded: actors_DB\Park_Bo-young\image_5.jpg
# Downloaded: actors_DB\Michele_Morrone\image_1.jpg
# Downloaded: actors_DB\Michele_Morrone\image_2.jpg
# Downloaded: actors_DB\Michele_Morrone\image_3.jpg
# Downloaded: actors_DB\Cecilia_Cheung\image_1.jpg
# Downloaded: actors_DB\Cecilia_Cheung\image_2.jpg
# Downloaded: actors_DB\Cecilia_Cheung\image_3.jpg
# Downloaded: actors_DB\Cecilia_Cheung\image_4.jpg
# Downloaded: actors_DB\Cecilia_Cheung\image_5.jpg
# Downloaded: actors_DB\Cemre_Baysel\image_1.jpg
# Downloaded: actors_DB\Cemre_Baysel\image_2.jpg
# Downloaded: actors_DB\Cemre_Baysel\image_3.jpg
# Downloaded: actors_DB\Cemre_Baysel\image_4.jpg
# Downloaded: actors_DB\Cemre_Baysel\image_5.jpg
# Downloaded: actors_DB\Jackson_Yee\image_1.jpg
# Downloaded: actors_DB\Jackson_Yee\image_2.jpg
# Downloaded: actors_DB\Jackson_Yee\image_3.jpg
# Downloaded: actors_DB\Jackson_Yee\image_4.jpg
# Downloaded: actors_DB\Jackson_Yee\image_5.jpg
# Downloaded: actors_DB\Nijiro_Murakami\image_1.jpg
# Downloaded: actors_DB\Nijiro_Murakami\image_2.jpg
# Downloaded: actors_DB\Nijiro_Murakami\image_3.jpg
# Downloaded: actors_DB\Nijiro_Murakami\image_4.jpg
# Downloaded: actors_DB\Cillian_Murphy\image_1.jpg
# Downloaded: actors_DB\Cillian_Murphy\image_2.jpg
# Downloaded: actors_DB\Cillian_Murphy\image_3.jpg
# Downloaded: actors_DB\Cillian_Murphy\image_4.jpg
# Downloaded: actors_DB\Cillian_Murphy\image_5.jpg
# Downloaded: actors_DB\George_Clooney\image_1.jpg
# Downloaded: actors_DB\George_Clooney\image_2.jpg
# Downloaded: actors_DB\George_Clooney\image_3.jpg
# Downloaded: actors_DB\George_Clooney\image_4.jpg
# Downloaded: actors_DB\George_Clooney\image_5.jpg
# Downloaded: actors_DB\Dylan_Wang\image_1.jpg
# Downloaded: actors_DB\Dylan_Wang\image_2.jpg
# Downloaded: actors_DB\Dylan_Wang\image_3.jpg
# Downloaded: actors_DB\Dylan_Wang\image_4.jpg
# Downloaded: actors_DB\Dylan_Wang\image_5.jpg
# Downloaded: actors_DB\Angelina_Jolie\image_1.jpg
# Downloaded: actors_DB\Angelina_Jolie\image_2.jpg
# Downloaded: actors_DB\Angelina_Jolie\image_3.jpg
# Downloaded: actors_DB\Angelina_Jolie\image_4.jpg
# Downloaded: actors_DB\Angelina_Jolie\image_5.jpg
# Downloaded: actors_DB\Wang_Tianchen\image_1.jpg
# Downloaded: actors_DB\Wang_Tianchen\image_2.jpg
# Downloaded: actors_DB\Wang_Tianchen\image_3.jpg
# Downloaded: actors_DB\Wang_Tianchen\image_4.jpg
# Downloaded: actors_DB\Wang_Tianchen\image_5.jpg
# Downloaded: actors_DB\James_Marsden\image_1.jpg
# Downloaded: actors_DB\James_Marsden\image_2.jpg
# Downloaded: actors_DB\James_Marsden\image_3.jpg
# Downloaded: actors_DB\James_Marsden\image_4.jpg
# Downloaded: actors_DB\James_Marsden\image_5.jpg
# Downloaded: actors_DB\White_Sugar\image_1.jpg
# Downloaded: actors_DB\White_Sugar\image_2.jpg
# Downloaded: actors_DB\White_Sugar\image_3.jpg
# Downloaded: actors_DB\Adrien_Brody\image_1.jpg
# Downloaded: actors_DB\Adrien_Brody\image_2.jpg
# Downloaded: actors_DB\Adrien_Brody\image_3.jpg
# Downloaded: actors_DB\Adrien_Brody\image_4.jpg
# Downloaded: actors_DB\Adrien_Brody\image_5.jpg
# Downloaded: actors_DB\Nicolas_Cage\image_1.jpg
# Downloaded: actors_DB\Nicolas_Cage\image_2.jpg
# Downloaded: actors_DB\Nicolas_Cage\image_3.jpg
# Downloaded: actors_DB\Nicolas_Cage\image_4.jpg
# Downloaded: actors_DB\Nicolas_Cage\image_5.jpg
# Downloaded: actors_DB\Uma_Thurman\image_1.jpg
# Downloaded: actors_DB\Uma_Thurman\image_2.jpg
# Downloaded: actors_DB\Uma_Thurman\image_3.jpg
# Downloaded: actors_DB\Uma_Thurman\image_4.jpg
# Downloaded: actors_DB\Uma_Thurman\image_5.jpg
# Downloaded: actors_DB\Matthew_Broome\image_1.jpg
# Downloaded: actors_DB\Edison_Chen\image_1.jpg
# Downloaded: actors_DB\Edison_Chen\image_2.jpg
# Downloaded: actors_DB\Audrey_Avila\image_1.jpg
# Downloaded: actors_DB\Saori_Hayami\image_1.jpg
# Downloaded: actors_DB\Saori_Hayami\image_2.jpg
# Downloaded: actors_DB\Saori_Hayami\image_3.jpg
# Downloaded: actors_DB\Saori_Hayami\image_4.jpg
# Downloaded: actors_DB\Saori_Hayami\image_5.jpg
# Downloaded: actors_DB\Jake_Gyllenhaal\image_1.jpg
# Downloaded: actors_DB\Jake_Gyllenhaal\image_2.jpg
# Downloaded: actors_DB\Jake_Gyllenhaal\image_3.jpg
# Downloaded: actors_DB\Jake_Gyllenhaal\image_4.jpg
# Downloaded: actors_DB\Jake_Gyllenhaal\image_5.jpg
# Downloaded: actors_DB\Aubrey_Plaza\image_1.jpg
# Downloaded: actors_DB\Aubrey_Plaza\image_2.jpg
# Downloaded: actors_DB\Aubrey_Plaza\image_3.jpg
# Downloaded: actors_DB\Aubrey_Plaza\image_4.jpg
# Downloaded: actors_DB\Aubrey_Plaza\image_5.jpg
# Downloaded: actors_DB\Mark_Wahlberg\image_1.jpg
# Downloaded: actors_DB\Mark_Wahlberg\image_2.jpg
# Downloaded: actors_DB\Mark_Wahlberg\image_3.jpg
# Downloaded: actors_DB\Mark_Wahlberg\image_4.jpg
# Downloaded: actors_DB\Mark_Wahlberg\image_5.jpg
# Downloaded: actors_DB\Dakota_Johnson\image_1.jpg
# Downloaded: actors_DB\Dakota_Johnson\image_2.jpg
# Downloaded: actors_DB\Dakota_Johnson\image_3.jpg
# Downloaded: actors_DB\Dakota_Johnson\image_4.jpg
# Downloaded: actors_DB\Dakota_Johnson\image_5.jpg
# Downloaded: actors_DB\Bill_Skarsgård\image_1.jpg
# Downloaded: actors_DB\Bill_Skarsgård\image_2.jpg
# Downloaded: actors_DB\Bill_Skarsgård\image_3.jpg
# Downloaded: actors_DB\Bill_Skarsgård\image_4.jpg
# Downloaded: actors_DB\Bill_Skarsgård\image_5.jpg
# Downloaded: actors_DB\Johnny_Depp\image_1.jpg
# Downloaded: actors_DB\Johnny_Depp\image_2.jpg
# Downloaded: actors_DB\Johnny_Depp\image_3.jpg
# Downloaded: actors_DB\Johnny_Depp\image_4.jpg
# Downloaded: actors_DB\Johnny_Depp\image_5.jpg
# Downloaded: actors_DB\Matt_Damon\image_1.jpg
# Downloaded: actors_DB\Matt_Damon\image_2.jpg
# Downloaded: actors_DB\Matt_Damon\image_3.jpg
# Downloaded: actors_DB\Matt_Damon\image_4.jpg
# Downloaded: actors_DB\Matt_Damon\image_5.jpg
# Downloaded: actors_DB\Steve_Zahn\image_1.jpg
# Downloaded: actors_DB\Steve_Zahn\image_2.jpg
# Downloaded: actors_DB\Steve_Zahn\image_3.jpg
# Downloaded: actors_DB\Steve_Zahn\image_4.jpg
# Downloaded: actors_DB\Ayaka_Miyoshi\image_1.jpg
# Downloaded: actors_DB\Ayaka_Miyoshi\image_2.jpg
# Downloaded: actors_DB\Ayaka_Miyoshi\image_3.jpg
# Downloaded: actors_DB\Rowan_Atkinson\image_1.jpg
# Downloaded: actors_DB\Rowan_Atkinson\image_2.jpg
# Downloaded: actors_DB\Rowan_Atkinson\image_3.jpg
# Downloaded: actors_DB\Rowan_Atkinson\image_4.jpg
# Downloaded: actors_DB\Rowan_Atkinson\image_5.jpg
# Downloaded: actors_DB\Zoe_Moore\image_1.jpg
# Downloaded: actors_DB\Choi_Hyun-wook\image_1.jpg
# Downloaded: actors_DB\Choi_Hyun-wook\image_2.jpg
# Downloaded: actors_DB\Choi_Hyun-wook\image_3.jpg
# Downloaded: actors_DB\Choi_Hyun-wook\image_4.jpg
# Downloaded: actors_DB\Choi_Hyun-wook\image_5.jpg
# Downloaded: actors_DB\Morgan_Freeman\image_1.jpg
# Downloaded: actors_DB\Morgan_Freeman\image_2.jpg
# Downloaded: actors_DB\Morgan_Freeman\image_3.jpg
# Downloaded: actors_DB\Morgan_Freeman\image_4.jpg
# Downloaded: actors_DB\Morgan_Freeman\image_5.jpg
# Downloaded: actors_DB\Travis_Fimmel\image_1.jpg
# Downloaded: actors_DB\Travis_Fimmel\image_2.jpg
# Downloaded: actors_DB\Travis_Fimmel\image_3.jpg
# Downloaded: actors_DB\Travis_Fimmel\image_4.jpg
# Downloaded: actors_DB\Travis_Fimmel\image_5.jpg
# Downloaded: actors_DB\Russell_Crowe\image_1.jpg
# Downloaded: actors_DB\Russell_Crowe\image_2.jpg
# Downloaded: actors_DB\Russell_Crowe\image_3.jpg
# Downloaded: actors_DB\Russell_Crowe\image_4.jpg
# Downloaded: actors_DB\Russell_Crowe\image_5.jpg
# Downloaded: actors_DB\Eddie_Redmayne\image_1.jpg
# Downloaded: actors_DB\Eddie_Redmayne\image_2.jpg
# Downloaded: actors_DB\Eddie_Redmayne\image_3.jpg
# Downloaded: actors_DB\Eddie_Redmayne\image_4.jpg
# Downloaded: actors_DB\Eddie_Redmayne\image_5.jpg
# Downloaded: actors_DB\Gong_Yoo\image_1.jpg
# Downloaded: actors_DB\Gong_Yoo\image_2.jpg
# Downloaded: actors_DB\Gong_Yoo\image_3.jpg
# Downloaded: actors_DB\Gong_Yoo\image_4.jpg
# Downloaded: actors_DB\Gong_Yoo\image_5.jpg
# Downloaded: actors_DB\Jim_Carrey\image_1.jpg
# Downloaded: actors_DB\Jim_Carrey\image_2.jpg
# Downloaded: actors_DB\Jim_Carrey\image_3.jpg
# Downloaded: actors_DB\Jim_Carrey\image_4.jpg
# Downloaded: actors_DB\Jim_Carrey\image_5.jpg
# Downloaded: actors_DB\Charlize_Theron\image_1.jpg
# Downloaded: actors_DB\Charlize_Theron\image_2.jpg
# Downloaded: actors_DB\Charlize_Theron\image_3.jpg
# Downloaded: actors_DB\Charlize_Theron\image_4.jpg
# Downloaded: actors_DB\Charlize_Theron\image_5.jpg
# Downloaded: actors_DB\Oprah_Winfrey\image_1.jpg
# Downloaded: actors_DB\Oprah_Winfrey\image_2.jpg
# Downloaded: actors_DB\Cha_Eun-woo\image_1.jpg
# Downloaded: actors_DB\Cha_Eun-woo\image_2.jpg
# Downloaded: actors_DB\Cha_Eun-woo\image_3.jpg
# Downloaded: actors_DB\Cha_Eun-woo\image_4.jpg
# Downloaded: actors_DB\Cha_Eun-woo\image_5.jpg
# Downloaded: actors_DB\Baek_Se-ri\image_1.jpg
# Downloaded: actors_DB\Yvonne_Strahovski\image_1.jpg
# Downloaded: actors_DB\Yvonne_Strahovski\image_2.jpg
# Downloaded: actors_DB\Yvonne_Strahovski\image_3.jpg
# Downloaded: actors_DB\Yvonne_Strahovski\image_4.jpg
# Downloaded: actors_DB\Yvonne_Strahovski\image_5.jpg
# Downloaded: actors_DB\Ji_Eun-seo\image_1.jpg
# Downloaded: actors_DB\Mads_Mikkelsen\image_1.jpg
# Downloaded: actors_DB\Mads_Mikkelsen\image_2.jpg
# Downloaded: actors_DB\Mads_Mikkelsen\image_3.jpg
# Downloaded: actors_DB\Mads_Mikkelsen\image_4.jpg
# Downloaded: actors_DB\Mads_Mikkelsen\image_5.jpg
# Downloaded: actors_DB\Bo_Derek\image_1.jpg
# Downloaded: actors_DB\Bo_Derek\image_2.jpg
# Downloaded: actors_DB\Bo_Derek\image_3.jpg
# Downloaded: actors_DB\Bo_Derek\image_4.jpg
# Downloaded: actors_DB\Bo_Derek\image_5.jpg
# Downloaded: actors_DB\Yang_Zi\image_1.jpg
# Downloaded: actors_DB\Yang_Zi\image_2.jpg
# Downloaded: actors_DB\Yang_Zi\image_3.jpg
# Downloaded: actors_DB\Yang_Zi\image_4.jpg
# Downloaded: actors_DB\Yang_Zi\image_5.jpg
# Downloaded: actors_DB\Monica_Bellucci\image_1.jpg
# Downloaded: actors_DB\Monica_Bellucci\image_2.jpg
# Downloaded: actors_DB\Monica_Bellucci\image_3.jpg
# Downloaded: actors_DB\Monica_Bellucci\image_4.jpg
# Downloaded: actors_DB\Monica_Bellucci\image_5.jpg
# Downloaded: actors_DB\Joey_King\image_1.jpg
# Downloaded: actors_DB\Joey_King\image_2.jpg
# Downloaded: actors_DB\Joey_King\image_3.jpg
# Downloaded: actors_DB\Joey_King\image_4.jpg
# Downloaded: actors_DB\Joey_King\image_5.jpg
# Downloaded: actors_DB\Ryan_Gosling\image_1.jpg
# Downloaded: actors_DB\Ryan_Gosling\image_2.jpg
# Downloaded: actors_DB\Ryan_Gosling\image_3.jpg
# Downloaded: actors_DB\Ryan_Gosling\image_4.jpg
# Downloaded: actors_DB\Ryan_Gosling\image_5.jpg
# Downloaded: actors_DB\Deepika_Padukone\image_1.jpg
# Downloaded: actors_DB\Deepika_Padukone\image_2.jpg
# Downloaded: actors_DB\Deepika_Padukone\image_3.jpg
# Downloaded: actors_DB\Deepika_Padukone\image_4.jpg
# Downloaded: actors_DB\Deepika_Padukone\image_5.jpg
# Downloaded: actors_DB\Florence_Pugh\image_1.jpg
# Downloaded: actors_DB\Florence_Pugh\image_2.jpg
# Downloaded: actors_DB\Florence_Pugh\image_3.jpg
# Downloaded: actors_DB\Florence_Pugh\image_4.jpg
# Downloaded: actors_DB\Florence_Pugh\image_5.jpg
# Downloaded: actors_DB\Nicholas_Hoult\image_1.jpg
# Downloaded: actors_DB\Nicholas_Hoult\image_2.jpg
# Downloaded: actors_DB\Nicholas_Hoult\image_3.jpg
# Downloaded: actors_DB\Nicholas_Hoult\image_4.jpg
# Downloaded: actors_DB\Nicholas_Hoult\image_5.jpg
# Downloaded: actors_DB\Eva_Green\image_1.jpg
# Downloaded: actors_DB\Eva_Green\image_2.jpg
# Downloaded: actors_DB\Eva_Green\image_3.jpg
# Downloaded: actors_DB\Eva_Green\image_4.jpg
# Downloaded: actors_DB\Eva_Green\image_5.jpg
# Downloaded: actors_DB\Apple_Dy\image_1.jpg
# Downloaded: actors_DB\Sandra_Bullock\image_1.jpg
# Downloaded: actors_DB\Sandra_Bullock\image_2.jpg
# Downloaded: actors_DB\Sandra_Bullock\image_3.jpg
# Downloaded: actors_DB\Sandra_Bullock\image_4.jpg
# Downloaded: actors_DB\Sandra_Bullock\image_5.jpg
# Downloaded: actors_DB\Zhang_Ruonan\image_1.jpg
# Downloaded: actors_DB\Zhang_Ruonan\image_2.jpg
# Downloaded: actors_DB\Zhang_Ruonan\image_3.jpg
# Downloaded: actors_DB\Zhang_Ruonan\image_4.jpg
# Downloaded: actors_DB\Zhang_Ruonan\image_5.jpg
# Downloaded: actors_DB\Jon_Beavers\image_1.jpg
# Downloaded: actors_DB\Matilda_Källström\image_1.jpg
# Downloaded: actors_DB\Matilda_Källström\image_2.jpg
# Downloaded: actors_DB\Jason_Momoa\image_1.jpg
# Downloaded: actors_DB\Jason_Momoa\image_2.jpg
# Downloaded: actors_DB\Jason_Momoa\image_3.jpg
# Downloaded: actors_DB\Jason_Momoa\image_4.jpg
# Downloaded: actors_DB\Jason_Momoa\image_5.jpg
# Downloaded: actors_DB\Kim_Soo-ji\image_1.jpg
# Downloaded: actors_DB\Emma_Stone\image_1.jpg
# Downloaded: actors_DB\Emma_Stone\image_2.jpg
# Downloaded: actors_DB\Emma_Stone\image_3.jpg
# Downloaded: actors_DB\Emma_Stone\image_4.jpg
# Downloaded: actors_DB\Emma_Stone\image_5.jpg
# Downloaded: actors_DB\Roh_Jae-won\image_1.jpg
# Downloaded: actors_DB\Jakrapatr_Kaewpanpong\image_1.jpg
# Downloaded: actors_DB\Jakrapatr_Kaewpanpong\image_2.jpg
# Downloaded: actors_DB\Jakrapatr_Kaewpanpong\image_3.jpg
# Downloaded: actors_DB\Yeung_Si-min\image_1.jpg
# Downloaded: actors_DB\Yeung_Si-min\image_2.jpg
# Downloaded: actors_DB\Yeung_Si-min\image_3.jpg
# Downloaded: actors_DB\Yeung_Si-min\image_4.jpg
# Downloaded: actors_DB\Morena_Baccarin\image_1.jpg
# Downloaded: actors_DB\Morena_Baccarin\image_2.jpg
# Downloaded: actors_DB\Morena_Baccarin\image_3.jpg
# Downloaded: actors_DB\Morena_Baccarin\image_4.jpg
# Downloaded: actors_DB\Morena_Baccarin\image_5.jpg
# Downloaded: actors_DB\Dina_Meyer\image_1.jpg
# Downloaded: actors_DB\Dina_Meyer\image_2.jpg
# Downloaded: actors_DB\Dina_Meyer\image_3.jpg
# Downloaded: actors_DB\Dina_Meyer\image_4.jpg
# Downloaded: actors_DB\Dina_Meyer\image_5.jpg
# Downloaded: actors_DB\Sarah_Shahi\image_1.jpg
# Downloaded: actors_DB\Sarah_Shahi\image_2.jpg
# Downloaded: actors_DB\Sarah_Shahi\image_3.jpg
# Downloaded: actors_DB\Sarah_Shahi\image_4.jpg
# Downloaded: actors_DB\Sarah_Shahi\image_5.jpg
# Downloaded: actors_DB\Dawn_Olivieri\image_1.jpg
# Downloaded: actors_DB\Jack_Quaid\image_1.jpg
# Downloaded: actors_DB\Jack_Quaid\image_2.jpg
# Downloaded: actors_DB\Jack_Quaid\image_3.jpg
# Downloaded: actors_DB\Jack_Quaid\image_4.jpg
# Downloaded: actors_DB\Austin_Butler\image_1.jpg
# Downloaded: actors_DB\Austin_Butler\image_2.jpg
# Downloaded: actors_DB\Austin_Butler\image_3.jpg
# Downloaded: actors_DB\Austin_Butler\image_4.jpg
# Downloaded: actors_DB\Austin_Butler\image_5.jpg
# Downloaded: actors_DB\Kang_Eun-hye\image_1.jpg
# Downloaded: actors_DB\Kang_Eun-hye\image_2.jpg
# Downloaded: actors_DB\Kang_Eun-hye\image_3.jpg
# Downloaded: actors_DB\Kang_Eun-hye\image_4.jpg
# Downloaded: actors_DB\Kang_Eun-hye\image_5.jpg
# Downloaded: actors_DB\Aaron_Taylor-Johnson\image_1.jpg
# Downloaded: actors_DB\Aaron_Taylor-Johnson\image_2.jpg
# Downloaded: actors_DB\Aaron_Taylor-Johnson\image_3.jpg
# Downloaded: actors_DB\Aaron_Taylor-Johnson\image_4.jpg
# Downloaded: actors_DB\Aaron_Taylor-Johnson\image_5.jpg
# Downloaded: actors_DB\Yoo_Ji-won\image_1.jpg
# Downloaded: actors_DB\Shuya_Sophia_Cai\image_1.jpg
# Downloaded: actors_DB\Shuya_Sophia_Cai\image_2.jpg
# Downloaded: actors_DB\Rowoon\image_1.jpg
# Downloaded: actors_DB\Rowoon\image_2.jpg
# Downloaded: actors_DB\Rowoon\image_3.jpg
# Downloaded: actors_DB\Rowoon\image_4.jpg
# Downloaded: actors_DB\Tanner_Buchanan\image_1.jpg
# Downloaded: actors_DB\Alyvia_Alyn_Lind\image_1.jpg
# Downloaded: actors_DB\Alyvia_Alyn_Lind\image_2.jpg
# Downloaded: actors_DB\Alyvia_Alyn_Lind\image_3.jpg
# Downloaded: actors_DB\Alyvia_Alyn_Lind\image_4.jpg
# Downloaded: actors_DB\Alyvia_Alyn_Lind\image_5.jpg
# Downloaded: actors_DB\Claire_Forlani\image_1.jpg
# Downloaded: actors_DB\Claire_Forlani\image_2.jpg
# Downloaded: actors_DB\Claire_Forlani\image_3.jpg
# Downloaded: actors_DB\Claire_Forlani\image_4.jpg
# Downloaded: actors_DB\Claire_Forlani\image_5.jpg
# Downloaded: actors_DB\Leya_Kırşan\image_1.jpg
# Downloaded: actors_DB\Leya_Kırşan\image_2.jpg
# Downloaded: actors_DB\Leya_Kırşan\image_3.jpg
# Downloaded: actors_DB\Yui_Aragaki\image_1.jpg
# Downloaded: actors_DB\Yui_Aragaki\image_2.jpg
# Downloaded: actors_DB\Yui_Aragaki\image_3.jpg
# Downloaded: actors_DB\Yui_Aragaki\image_4.jpg
# Downloaded: actors_DB\Yui_Aragaki\image_5.jpg
# Downloaded: actors_DB\Jacob_Elordi\image_1.jpg
# Downloaded: actors_DB\Jacob_Elordi\image_2.jpg
# Downloaded: actors_DB\Jacob_Elordi\image_3.jpg
# Downloaded: actors_DB\Jacob_Elordi\image_4.jpg
# Downloaded: actors_DB\Jacob_Elordi\image_5.jpg
# Downloaded: actors_DB\Elisha_Cuthbert\image_1.jpg
# Downloaded: actors_DB\Elisha_Cuthbert\image_2.jpg
# Downloaded: actors_DB\Elisha_Cuthbert\image_3.jpg
# Downloaded: actors_DB\Elisha_Cuthbert\image_4.jpg
# Downloaded: actors_DB\Elisha_Cuthbert\image_5.jpg
# Image download complete!

# %%
# test to see how popular actors are returned from the API

# url = "https://api.themoviedb.org/3/person/popular?language=en-US&page=1"

# headers = {
#     "accept": "application/json",
#     "Authorization": f"Bearer {api_key}"

# response = requests.get(url, headers=headers)

# if response.status_code == 200:
#     data = response.json()
#     actors = [(person["id"], person["name"]) for person in data.get("results", []) if person.get("known_for_department") == "Acting"]
#     print(actors)
# else:
#     print("Error:", response.status_code, response.text)
# Out:
# [(1522703, 'Hande Erçel'), (109513, 'Alexandra Daddario'), (1190668, 'Timothée Chalamet'), (1397778, 'Anya Taylor-Joy'), (115440, 'Sydney Sweeney'), (2049994, 'Zhao Lusi'), (500, 'Tom Cruise'), (1245, 'Scarlett Johansson'), (1152083, 'Sabrina Carpenter'), (556435, 'Cho Yeo-jeong'), (976, 'Jason Statham'), (2786960, 'Gabriel Guevara'), (1981044, 'Sophie Thatcher'), (19189, 'Elizabeth Berkley'), (1813, 'Anne Hathaway'), (90570, 'Atsuko Takahata'), (974169, 'Jenna Ortega'), (1253360, 'Pedro Pascal'), (3371804, 'Christine Bermas'), (64, 'Gary Oldman')]

# %%
# # test to see how images are returned from the API

# url = "https://api.themoviedb.org/3/person/500/images"

# headers = {
#     "accept": "application/json",
#     "Authorization": "Bearer {api_key}"
# }

# response = requests.get(url, headers=headers)

# if response.status_code == 200:
#     data = response.json()  # Convert response to JSON
#     for image in data.get("profiles", []):  # Loop through "profiles" list
#         if "file_path" in image:
#             print(image["file_path"])  # Print only file path
# else:
#     print(f"Error: {response.status_code}")
# Out:
# /8qBylBsQf4llkGrWR3qAsOtOU8O.jpg
# /eOh4ubpOm2Igdg0QH2ghj0mFtC.jpg
# /5sjLDtdwjuVdZNdrnbAwDQdn5W.jpg
# /rZXZWW00hiZyVVBtXKBozAAq0Cf.jpg
# /vQFCioXTiCBBJaWeBDKD8mXZJ8V.jpg
# /pJetAUyfEesoEqg1uabXSXkEDMV.jpg
# /cMwXD3eiUfStgVh1gpVcwCnNelv.jpg
# /bn9CwMSM3o4XPZEPZdQ3grslGup.jpg
# /gextEr8Tz4qT7Cwv1Xc82S7cTHx.jpg
# /h6ShtVkFKOaBaWhAAUbdmHIpkak.jpg
# /2Dkx4uuGoWFrPSitxdikv9z5azR.jpg
# /9pTIJwjH3Wg8JAxt0TNTpu0cXK0.jpg
# /t5jC5DiXFRDBi1rzLy7ARh5RM5D.jpg
# /57wg0qQcS3OUl7euj1kQItGn05r.jpg
# /yUsSJ0vO8AM9HnDQWuGKMSzCKOP.jpg
# /maf8PhSvDCdEwjEMbYfGpojR5RP.jpg
# /3mShHjSQR7NXOVbdTu5rT2Qd0MN.jpg
# /A1pSJlh0XqU00Vkia7cFNonVHtf.jpg
# /kJXYRrcfIViRRnS27LYS14vndds.jpg
# /4CpJ4H1llv6dxqC8iLHoXVgpgqI.jpg
